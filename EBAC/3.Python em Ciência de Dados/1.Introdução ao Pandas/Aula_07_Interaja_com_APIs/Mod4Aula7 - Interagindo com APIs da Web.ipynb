# %% [markdown]
# # Interagindo com APIs da Web

# %% [markdown]
# ## Operações COPEM
# https://sisweb.tesouro.gov.br/apex/f?p=2941:2:::NO:RP,2:P2_ID_UNIDADE_STN:13
#
# SADIPEM API 1.1.0
# [ Base URL: apidatalake.tesouro.gov.br/ords/sadipem/tt/ ]
#
# - https://dados.gov.br/dataset/operacoes-copem
# - http://apidatalake.tesouro.gov.br/docs/sadipem/#/PVL%20-%20Dados%20B%C3%A1sicos
# - https://conteudo.tesouro.gov.br/manuais/index.php?option=com_content&view=article&id=3095&catid=63&Itemid=274
#
# Requests
# - https://docs.python-requests.org/en/master/

# %%
import pandas as pd
import requests

# %%
url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=SP&tipo_interessado=Estado'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
data_json['items']
# Out:
# [{'id_pleito': 5623,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000157/2002-58',
#   'data_protocolo': '2002-04-16T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 209000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '05/06/2002'},
#  {'id_pleito': 5006,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000022/2011-83',
#   'data_protocolo': '2011-10-10T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Japan International Cooperation Agency',
#   'moeda': 'Iene',
#   'valor': 33584000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '03/11/2011'},
#  {'id_pleito': 6774,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000427/2002-21',
#   'data_protocolo': '2002-05-27T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 290000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/06/2002'},
#  {'id_pleito': 6342,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000324/2008-56',
#   'data_protocolo': '2008-03-31T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1579000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '23/04/2008'},
#  {'id_pleito': 8619,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000811/2009-08',
#   'data_protocolo': '2009-10-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 64496000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/11/2009'},
#  {'id_pleito': 7056,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000487/2013-04',
#   'data_protocolo': '2015-12-16T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1500000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '23/09/2013'},
#  {'id_pleito': 12457,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001690/2011-28',
#   'data_protocolo': '2012-03-23T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 1148633000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '16/04/2012'},
#  {'id_pleito': 11453,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001452/2009-06',
#   'data_protocolo': '2009-11-18T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Japan Bank for International Cooperation',
#   'moeda': 'Dólar dos EUA',
#   'valor': 130000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/11/2009'},
#  {'id_pleito': 12548,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001710/2009-46',
#   'data_protocolo': '2010-07-01T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 326775000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '21/07/2010'},
#  {'id_pleito': 5317,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000084/2014-38',
#   'data_protocolo': '2014-01-23T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco do Brasil S/A',
#   'moeda': 'Real',
#   'valor': 1537318000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '26/02/2014'},
#  {'id_pleito': 11390,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001430/2010-71',
#   'data_protocolo': '2011-03-14T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Preservação e recuperação ambiental',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 115700000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '06/04/2011'},
#  {'id_pleito': 58411,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.001041/2022-17',
#   'status': 'Deferido',
#   'num_processo': '17944.101917/2022-97',
#   'data_protocolo': '2022-05-16T17:43:42Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'New Development Bank',
#   'moeda': 'Dólar dos EUA',
#   'valor': 90000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '31/05/2022'},
#  {'id_pleito': 11263,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Arquivado',
#   'num_processo': '17944.001396/2011-16',
#   'data_protocolo': '2011-09-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 748633000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '10/10/2011'},
#  {'id_pleito': 6985,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000473/2006-53',
#   'data_protocolo': '2007-02-28T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Multissetorial',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 10000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '06/03/2008'},
#  {'id_pleito': 5688,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000173/2004-11',
#   'data_protocolo': '2004-04-12T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1200000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '16/04/2004'},
#  {'id_pleito': 10836,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001297/2014-87',
#   'data_protocolo': '2015-11-13T15:12:11Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 690000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '04/02/2016'},
#  {'id_pleito': 7476,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000588/2014-58',
#   'data_protocolo': '2014-04-16T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1700000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '30/04/2014'},
#  {'id_pleito': 9433,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000981/2002-16',
#   'data_protocolo': '2003-11-28T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Japan Bank for International Cooperation',
#   'moeda': 'Iene',
#   'valor': 559308880,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '08/06/2004'},
#  {'id_pleito': 48051,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.002802/2021-77',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.103753/2021-51',
#   'data_protocolo': '2022-05-27T18:34:28Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Corporação Andina de Fomento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 550000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '31/05/2022'},
#  {'id_pleito': 5003,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000022/2004-54',
#   'data_protocolo': '2004-06-01T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Educação',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco do Estado de São Paulo S/A',
#   'moeda': 'Real',
#   'valor': 29820000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '04/06/2004'},
#  {'id_pleito': 6543,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000376/2014-71',
#   'data_protocolo': '2014-08-04T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Santander (Brasil) S.A.',
#   'moeda': 'Dólar dos EUA',
#   'valor': 300000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '21/08/2014'},
#  {'id_pleito': 9180,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000920/2008-36',
#   'data_protocolo': '2008-09-10T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'PMAE',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 15000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '19/09/2008'},
#  {'id_pleito': 9257,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000939/2009-63',
#   'data_protocolo': '2009-10-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Aquisição de terrenos, imóveis e/ou construção de instalações',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 240000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/11/2009'},
#  {'id_pleito': 7906,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000675/2009-48',
#   'data_protocolo': '2009-08-14T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 600000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '26/08/2009'},
#  {'id_pleito': 9034,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000889/2013-09',
#   'data_protocolo': '2013-10-22T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'PAC 2 - Mobilidade Médias Cidades',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 400000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '26/12/2013'},
#  {'id_pleito': 10502,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001216/2013-68',
#   'data_protocolo': '2014-01-23T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 480135000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '27/02/2014'},
#  {'id_pleito': 70255,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.002282/2024-45',
#   'status': 'Em análise',
#   'num_processo': '17944.007329/2024-20',
#   'data_protocolo': '2024-12-30T16:34:39Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Aporte em PPP',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 3200000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '30/12/2024'},
#  {'id_pleito': 30127,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.002421/2018-92',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.109290/2018-36',
#   'data_protocolo': '2019-06-24T12:19:43Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Profisco',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 87120000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '10/07/2019'},
#  {'id_pleito': 11763,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001521/2009-73',
#   'data_protocolo': '2010-08-17T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 112910000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/08/2010'},
#  {'id_pleito': 18661,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': '00000.000000/1003-61',
#   'status': 'Deferido',
#   'num_processo': '17944.000345/2015-09',
#   'data_protocolo': '2017-04-24T11:46:59Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 475989894.47,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '10/05/2017'},
#  {'id_pleito': 11585,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001482/2007-42',
#   'data_protocolo': '2007-11-27T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Sumitomo Mitsui Banking Corporation',
#   'moeda': 'Dólar dos EUA',
#   'valor': 95000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '13/05/2008'},
#  {'id_pleito': 34018,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.001842/2019-87',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.102767/2019-33',
#   'data_protocolo': '2019-08-19T18:04:08Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco do Brasil S/A',
#   'moeda': 'Real',
#   'valor': 900000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 1,
#   'data_status': '30/08/2019'},
#  {'id_pleito': 12416,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001682/2007-03',
#   'data_protocolo': '2007-12-13T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Aquisição de máquinas, equipamentos e veículos',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Sumitomo Mitsui Banking Corporation',
#   'moeda': 'Dólar dos EUA',
#   'valor': 535000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '13/05/2008'},
#  {'id_pleito': 7947,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000682/2014-15',
#   'data_protocolo': '2014-06-11T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 480135000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '15/08/2014'},
#  {'id_pleito': 11248,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Arquivado',
#   'num_processo': '17944.001393/2011-82',
#   'data_protocolo': '2011-09-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 400000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '10/10/2011'},
#  {'id_pleito': 12884,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001836/2014-88',
#   'data_protocolo': '2014-12-05T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1650000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '18/12/2014'},
#  {'id_pleito': 11488,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001460/2008-63',
#   'data_protocolo': '2009-10-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 4000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/11/2009'},
#  {'id_pleito': 11458,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001453/2009-42',
#   'data_protocolo': '2009-11-18T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 650412000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/11/2009'},
#  {'id_pleito': 11493,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001461/2008-16',
#   'data_protocolo': '2008-08-20T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 100000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '27/08/2008'},
#  {'id_pleito': 67175,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.003851/2023-99',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.105293/2023-68',
#   'data_protocolo': '2024-02-28T14:47:28Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 3605000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '14/03/2024'},
#  {'id_pleito': 69875,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.001921/2024-55',
#   'status': 'Em retificação pelo interessado',
#   'num_processo': '17944.006382/2024-11',
#   'data_protocolo': '2024-11-07T16:27:09Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 250000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '11/11/2024'},
#  {'id_pleito': 60909,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.007161/2022-28',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.102887/2022-36',
#   'data_protocolo': '2023-09-12T14:03:02Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Multissetorial',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 164237344,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '27/09/2023'},
#  {'id_pleito': 11522,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001467/2008-85',
#   'data_protocolo': '2009-03-20T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 166650000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '27/03/2009'},
#  {'id_pleito': 67164,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.003925/2023-97',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.105321/2023-47',
#   'data_protocolo': '2024-07-17T18:16:11Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Aporte em PPP',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 3200000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '30/07/2024'},
#  {'id_pleito': 10380,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001185/2010-01',
#   'data_protocolo': '2010-08-25T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'PAC - Copa Pró-Transporte',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 1082000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '30/08/2010'},
#  {'id_pleito': 5248,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000068/2013-64',
#   'data_protocolo': '2014-07-01T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Corporação Andina de Fomento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 200000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '07/08/2014'},
#  {'id_pleito': 5701,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000175/2013-92',
#   'data_protocolo': '2013-06-13T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Multissetorial',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 300000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '03/07/2013'},
#  {'id_pleito': 69594,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.001683/2024-88',
#   'status': 'Em retificação pelo credor',
#   'num_processo': '17944.005714/2024-32',
#   'data_protocolo': '2024-11-11T15:26:12Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 2400000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/11/2024'},
#  {'id_pleito': 5611,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000155/2002-69',
#   'data_protocolo': '2001-11-27T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 34000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '05/06/2002'},
#  {'id_pleito': 9123,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000908/2005-89',
#   'data_protocolo': '2005-07-28T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Preservação e recuperação ambiental',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 9000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/01/2006'},
#  {'id_pleito': 11638,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001493/2009-94',
#   'data_protocolo': '2009-12-17T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'PEF - Programa Emergencial de Financiamento dos Estados/DF',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 40000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '23/12/2009'},
#  {'id_pleito': 26940,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.002362/2017-71',
#   'status': 'Deferido',
#   'num_processo': '17944.103065/2017-13',
#   'data_protocolo': '2017-12-20T13:41:35Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Renegociação de dívidas',
#   'tipo_credor': 'União',
#   'credor': 'União',
#   'moeda': 'Real',
#   'valor': 223539966235.09,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '21/12/2017'},
#  {'id_pleito': 10615,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001242/2014-77',
#   'data_protocolo': '2014-08-13T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 982000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '03/09/2014'},
#  {'id_pleito': 10678,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001257/2010-10',
#   'data_protocolo': '2010-09-02T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 233700000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '02/09/2010'},
#  {'id_pleito': 6413,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000340/2003-34',
#   'data_protocolo': '2003-07-03T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Multissetorial',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 70664000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '06/05/2004'},
#  {'id_pleito': 6513,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000370/2013-12',
#   'data_protocolo': '2013-07-04T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Multissetorial',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco do Brasil S/A',
#   'moeda': 'Real',
#   'valor': 2000000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '13/08/2013'},
#  {'id_pleito': 8622,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000812/2009-44',
#   'data_protocolo': '2009-10-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Desenvolvimento sustentável',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 78000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/11/2009'},
#  {'id_pleito': 8284,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000749/2010-80',
#   'data_protocolo': '2010-06-24T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 766000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '23/06/2010'},
#  {'id_pleito': 11604,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001486/2007-21',
#   'data_protocolo': '2007-11-27T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 95000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '13/05/2008'},
#  {'id_pleito': 28862,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.001149/2018-23',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.105836/2018-80',
#   'data_protocolo': '2019-06-24T12:16:24Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Corporação Andina de Fomento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 296000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '10/07/2019'},
#  {'id_pleito': 4943,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000002/2008-15',
#   'data_protocolo': '2009-03-20T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Aquisição de máquinas, equipamentos e veículos',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 168000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '27/03/2009'},
#  {'id_pleito': 65870,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.002226/2023-20',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.102389/2023-74',
#   'data_protocolo': '2023-07-24T11:27:37Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 480133500,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '17/08/2023'},
#  {'id_pleito': 64331,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.000813/2023-84',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.101906/2023-98',
#   'data_protocolo': '2023-05-25T16:18:15Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1500000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '30/05/2023'},
#  {'id_pleito': 42155,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.008104/2019-61',
#   'status': 'Arquivado a pedido',
#   'num_processo': '17944.101324/2020-69',
#   'data_protocolo': '2020-05-06T17:13:40Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 300000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '19/02/2021'},
#  {'id_pleito': 8998,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000881/2013-34',
#   'data_protocolo': '2014-01-23T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Fortalecimento Institucional',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 270000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '26/02/2014'},
#  {'id_pleito': 7899,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000674/2009-01',
#   'data_protocolo': '2009-08-14T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Japan International Cooperation Agency',
#   'moeda': 'Dólar dos EUA',
#   'valor': 61461000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '26/08/2009'},
#  {'id_pleito': 5616,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000156/2002-11',
#   'data_protocolo': '2001-11-27T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 120000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '05/06/2002'},
#  {'id_pleito': 12382,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001673/2005-42',
#   'data_protocolo': '2007-02-28T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 30000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '20/12/2007'},
#  {'id_pleito': 9873,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001071/2004-12',
#   'data_protocolo': '2004-09-06T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 5000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/04/2005'},
#  {'id_pleito': 6561,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000379/2014-12',
#   'data_protocolo': '2014-03-17T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Europeu de Investimento',
#   'moeda': 'Euro',
#   'valor': 200000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/08/2014'},
#  {'id_pleito': 7061,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000488/2013-41',
#   'data_protocolo': '2013-06-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 800000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '16/07/2013'},
#  {'id_pleito': 8292,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000750/2010-12',
#   'data_protocolo': '2010-06-22T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'PEF - Programa Emergencial de Financiamento dos Estados/DF 2',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 60000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '01/07/2010'},
#  {'id_pleito': 40469,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.008761/2019-16',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.104318/2019-20',
#   'data_protocolo': '2022-05-27T18:39:09Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Preservação e recuperação ambiental',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 79866302,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '31/05/2022'},
#  {'id_pleito': 44005,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.000145/2021-23',
#   'status': 'Arquivado a pedido',
#   'num_processo': '17944.100806/2021-82',
#   'data_protocolo': '2022-06-21T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'New Development Bank',
#   'moeda': 'Dólar dos EUA',
#   'valor': 200000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '29/06/2022'},
#  {'id_pleito': 10752,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001274/2014-72',
#   'data_protocolo': '2014-08-22T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 938200000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '03/09/2014'},
#  {'id_pleito': 28104,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.000679/2018-54',
#   'status': 'Arquivado a pedido',
#   'num_processo': '17944.103011/2018-21',
#   'data_protocolo': '2018-08-15T18:17:10Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 900000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '05/02/2019'},
#  {'id_pleito': 31194,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.001922/2018-51',
#   'status': 'Deferido',
#   'num_processo': '17944.100826/2019-39',
#   'data_protocolo': '2019-03-21T17:48:34Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 300000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/04/2019'},
#  {'id_pleito': 11169,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001375/2012-81',
#   'data_protocolo': '2012-12-18T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Proinveste',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1958620268.68,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '03/01/2013'},
#  {'id_pleito': 12427,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001684/2007-94',
#   'data_protocolo': '2007-12-13T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Aquisição de máquinas, equipamentos e veículos',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 550000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '13/05/2008'},
#  {'id_pleito': 31195,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.000215/2019-29',
#   'status': 'Deferido',
#   'num_processo': '17944.100827/2019-83',
#   'data_protocolo': '2019-03-21T17:50:26Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 250000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '01/04/2019'},
#  {'id_pleito': 8098,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000712/2012-13',
#   'data_protocolo': '2012-05-14T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 550000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '04/06/2012'},
#  {'id_pleito': 11126,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001366/2009-95',
#   'data_protocolo': '2009-11-19T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 480958000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/11/2009'},
#  {'id_pleito': 13181,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001947/2013-11',
#   'data_protocolo': '2014-03-17T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 307000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '07/04/2014'},
#  {'id_pleito': 9030,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000888/2013-56',
#   'data_protocolo': '2013-10-22T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'PAC 2 - Mobilidade Médias Cidades',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 215000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '11/11/2013'},
#  {'id_pleito': 11505,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001464/2008-41',
#   'data_protocolo': '2008-09-10T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 194000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '19/09/2008'},
#  {'id_pleito': 28058,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.000587/2018-74',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.102744/2018-48',
#   'data_protocolo': '2018-04-25T09:36:06Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Santander (Brasil) S.A.',
#   'moeda': 'Real',
#   'valor': 250000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 1,
#   'data_status': '04/05/2018'},
#  {'id_pleito': 67621,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.004327/2023-35',
#   'status': 'Deferido',
#   'num_processo': '17944.000023/2024-42',
#   'data_protocolo': '2024-02-29T13:01:25Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Aporte em PPP',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1354898000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '13/03/2024'},
#  {'id_pleito': 10377,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001185/2003-73',
#   'data_protocolo': '2004-04-22T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Aquisição de terrenos, imóveis e/ou construção de instalações',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Sumitomo Mitsui Banking Corporation',
#   'moeda': 'Dólar dos EUA',
#   'valor': 209000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '07/07/2004'},
#  {'id_pleito': 10456,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001204/2009-57',
#   'data_protocolo': '2009-10-21T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Internacional para Reconstrução e Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 130000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/11/2009'},
#  {'id_pleito': 60069,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.005843/2022-04',
#   'status': 'Deferido',
#   'num_processo': '17944.102355/2022-07',
#   'data_protocolo': '2022-06-14T10:58:57Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'New Development Bank',
#   'moeda': 'Dólar dos EUA',
#   'valor': 300000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '24/06/2022'},
#  {'id_pleito': 51532,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.006462/2021-53',
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.104649/2021-84',
#   'data_protocolo': '2022-05-20T11:15:40Z',
#   'tipo_operacao': 'Operação contratual interna (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 1500000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/05/2022'},
#  {'id_pleito': 11755,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.001519/2009-02',
#   'data_protocolo': '2010-06-18T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Profisco',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 120000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '12/07/2010'},
#  {'id_pleito': 10223,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001148/2010-94',
#   'data_protocolo': '2010-09-16T00:00:00Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Japan International Cooperation Agency',
#   'moeda': 'Iene',
#   'valor': 19169000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '09/10/2010'},
#  {'id_pleito': 6536,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.000375/2012-64',
#   'data_protocolo': '2012-03-16T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Banco Nacional de Desenvolvimento Econômico e Social',
#   'moeda': 'Real',
#   'valor': 922000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '19/04/2012'},
#  {'id_pleito': 7053,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000486/2013-51',
#   'data_protocolo': '2014-01-31T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Agência Francesa de Desenvolvimento',
#   'moeda': 'Euro',
#   'valor': 300000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '05/03/2014'},
#  {'id_pleito': 7118,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000501/2013-61',
#   'data_protocolo': '2014-01-23T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Infraestrutura',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Corporação Andina de Fomento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 204000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '27/02/2014'},
#  {'id_pleito': 63653,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': 'PVL02.009168/2022-84',
#   'status': 'Deferido',
#   'num_processo': '17944.100901/2023-48',
#   'data_protocolo': '2023-03-16T10:27:41Z',
#   'tipo_operacao': 'Concessão de garantia',
#   'finalidade': 'Concessão de garantia a empresa estatal não dependente',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 110000000,
#   'pvl_assoc_divida': 0,
#   'pvl_contradado_credor': 0,
#   'data_status': '24/03/2023'},
#  {'id_pleito': 4931,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '10951.001032/2003-98',
#   'data_protocolo': '2003-12-12T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Fortalecimento Institucional',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 20000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '07/07/2004'},
#  {'id_pleito': 5223,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#   'num_processo': '17944.000063/2010-99',
#   'data_protocolo': '2010-08-18T00:00:00Z',
#   'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#   'finalidade': 'Preservação e recuperação ambiental',
#   'tipo_credor': 'Instituição Financeira Internacional',
#   'credor': 'Banco Interamericano de Desenvolvimento',
#   'moeda': 'Dólar dos EUA',
#   'valor': 162454000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '25/08/2010'},
#  {'id_pleito': 11982,
#   'tipo_interessado': 'Estado',
#   'interessado': 'São Paulo',
#   'cod_ibge': 35,
#   'uf': 'SP',
#   'num_pvl': None,
#   'status': 'Deferido',
#   'num_processo': '17944.001573/2009-40',
#   'data_protocolo': '2010-06-18T00:00:00Z',
#   'tipo_operacao': 'Operação contratual interna',
#   'finalidade': 'PAC - Saneamento - 2009 A',
#   'tipo_credor': 'Instituição Financeira Nacional',
#   'credor': 'Caixa Econômica Federal',
#   'moeda': 'Real',
#   'valor': 64000000,
#   'pvl_assoc_divida': 1,
#   'pvl_contradado_credor': 0,
#   'data_status': '24/06/2010'}]

# %%
pd.DataFrame(data_json['items'])
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0        5623           Estado   São Paulo        35  SP
# 1        5006           Estado   São Paulo        35  SP
# 2        6774           Estado   São Paulo        35  SP
# 3        6342           Estado   São Paulo        35  SP
# 4        8619           Estado   São Paulo        35  SP
# ..        ...              ...         ...       ...  ..
# 95       7118           Estado   São Paulo        35  SP
# 96      63653           Estado   São Paulo        35  SP
# 97       4931           Estado   São Paulo        35  SP
# 98       5223           Estado   São Paulo        35  SP
# 99      11982           Estado   São Paulo        35  SP
#
#                  num_pvl                                             status  \
# 0                   None  Encaminhado à PGFN com manifestação técnica fa...
# 1                   None                                           Deferido
# 2                   None                                           Deferido
# 3                   None                                           Deferido
# 4                   None  Encaminhado à PGFN com manifestação técnica fa...
# ..                   ...                                                ...
# 95                  None  Encaminhado à PGFN com manifestação técnica fa...
# 96  PVL02.009168/2022-84                                           Deferido
# 97                  None  Encaminhado à PGFN com manifestação técnica fa...
# 98                  None  Encaminhado à PGFN com manifestação técnica fa...
# 99                  None                                           Deferido
#
#             num_processo        data_protocolo  \
# 0   17944.000157/2002-58  2002-04-16T00:00:00Z
# 1   17944.000022/2011-83  2011-10-10T00:00:00Z
# 2   17944.000427/2002-21  2002-05-27T00:00:00Z
# 3   17944.000324/2008-56  2008-03-31T00:00:00Z
# 4   17944.000811/2009-08  2009-10-21T00:00:00Z
# ..                   ...                   ...
# 95  17944.000501/2013-61  2014-01-23T00:00:00Z
# 96  17944.100901/2023-48  2023-03-16T10:27:41Z
# 97  10951.001032/2003-98  2003-12-12T00:00:00Z
# 98  17944.000063/2010-99  2010-08-18T00:00:00Z
# 99  17944.001573/2009-40  2010-06-18T00:00:00Z
#
#                                         tipo_operacao  \
# 0   Operação contratual externa (com garantia da U...
# 1                               Concessão de garantia
# 2                         Operação contratual interna
# 3                         Operação contratual interna
# 4   Operação contratual externa (com garantia da U...
# ..                                                ...
# 95  Operação contratual externa (com garantia da U...
# 96                              Concessão de garantia
# 97  Operação contratual externa (com garantia da U...
# 98  Operação contratual externa (com garantia da U...
# 99                        Operação contratual interna
#
#                                            finalidade  \
# 0                                      Infraestrutura
# 1   Concessão de garantia a empresa estatal não de...
# 2                                      Infraestrutura
# 3                                      Infraestrutura
# 4                                      Infraestrutura
# ..                                                ...
# 95                                     Infraestrutura
# 96  Concessão de garantia a empresa estatal não de...
# 97                       Fortalecimento Institucional
# 98                Preservação e recuperação ambiental
# 99                          PAC - Saneamento - 2009 A
#
#                              tipo_credor  \
# 0   Instituição Financeira Internacional
# 1   Instituição Financeira Internacional
# 2        Instituição Financeira Nacional
# 3        Instituição Financeira Nacional
# 4   Instituição Financeira Internacional
# ..                                   ...
# 95  Instituição Financeira Internacional
# 96  Instituição Financeira Internacional
# 97  Instituição Financeira Internacional
# 98  Instituição Financeira Internacional
# 99       Instituição Financeira Nacional
#
#                                                credor          moeda  \
# 0   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1              Japan International Cooperation Agency           Iene
# 2   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# ..                                                ...            ...
# 95                       Corporação Andina de Fomento  Dólar dos EUA
# 96            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 97            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 98            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 99                            Caixa Econômica Federal           Real
#
#            valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   2.090000e+08                 1                      0  05/06/2002
# 1   3.358400e+10                 1                      0  03/11/2011
# 2   2.900000e+08                 1                      0  25/06/2002
# 3   1.579000e+09                 1                      0  23/04/2008
# 4   6.449600e+07                 1                      0  12/11/2009
# ..           ...               ...                    ...         ...
# 95  2.040000e+08                 1                      0  27/02/2014
# 96  1.100000e+08                 0                      0  24/03/2023
# 97  2.000000e+07                 1                      0  07/07/2004
# 98  1.624540e+08                 1                      0  25/08/2010
# 99  6.400000e+07                 1                      0  24/06/2010
#
# [100 rows x 18 columns]
