# %%
import numpy  as np
import pandas as pd

# %% [markdown]
# # Operações com ``DataFrame``

# %% [markdown]
# ## Criando 2 dataframes (3 x 5)

# %%
np.random.randint(10, size=(3, 5))
# Out:
# array([[9, 7, 5, 7, 8],
#        [4, 0, 5, 8, 0],
#        [0, 5, 8, 8, 0]], dtype=int32)

# %%
df1 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df1
# Out:
#    A  B  C  D  E
# 0  4  6  3  2  0
# 1  6  9  2  1  5
# 2  6  5  0  5  0

# %%
df2 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df2
# Out:
#    A  B  C  D  E
# 0  3  6  5  9  0
# 1  7  4  3  4  0
# 2  7  0  7  3  7

# %% [markdown]
# ## Somando 2 dataframes (3 x 5)

# %%
df1 + df2
# Out:
#     A   B  C   D  E
# 0   7  12  8  11  0
# 1  13  13  5   5  5
# 2  13   5  7   8  7

# %% [markdown]
# ## Criando 1 dataframe (1 x 5)

# %%
df3 = pd.DataFrame(np.random.randint(10, size=(1, 5)), columns=['A','B','C','D','E'])
df3
# Out:
#    A  B  C  D  E
# 0  8  6  5  1  5

# %% [markdown]
# ## Somando 2 dataframes (3 x 5 e 1 x 5)

# %%
df1 + df3
# Out:
#       A     B    C    D    E
# 0  12.0  12.0  8.0  3.0  5.0
# 1   NaN   NaN  NaN  NaN  NaN
# 2   NaN   NaN  NaN  NaN  NaN

# %% [markdown]
# ## Zerando uma linha

# %%
df1
# Out:
#    A  B  C  D  E
# 0  4  6  3  2  0
# 1  6  9  2  1  5
# 2  6  5  0  5  0

# %%
df1.iloc[0]
# Out:
# A    4
# B    6
# C    3
# D    2
# E    0
# Name: 0, dtype: int32

# %%
df1 - df1.iloc[0]
# Out:
#    A  B  C  D  E
# 0  0  0  0  0  0
# 1  3 -6  1  0  3
# 2  6 -3  0 -7  4

# %% [markdown]
# ## Operação com escalar

# %%
df1
# Out:
#    A  B  C  D  E
# 0  2  3  7  7  5
# 1  3  1  4  1  5
# 2  4  7  2  4  5

# %%
df1 * 100
# Out:
#      A    B    C    D    E
# 0  200  300  700  700  500
# 1  300  100  400  100  500
# 2  400  700  200  400  500

# %%
df1 * 100 + 200
# Out:
#      A    B    C     D     E
# 0  700  300  600   200   500
# 1  600  900  200  1000  1000
# 2  900  900  900   200   700

# %% [markdown]
# ## Transpondo df

# %%
df1
# Out:
#    A  B  C  D  E
# 0  2  3  7  7  5
# 1  3  1  4  1  5
# 2  4  7  2  4  5

# %%
df1.T
# Out:
#    0  1  2
# A  2  3  4
# B  3  1  7
# C  7  4  2
# D  7  1  4
# E  5  5  5

# %% [markdown]
# ## Calculando exponencial dos valores

# %%
np.exp(df1)
# Out:
#            A            B            C            D           E
# 0   7.389056    20.085537  1096.633158  1096.633158  148.413159
# 1  20.085537     2.718282    54.598150     2.718282  148.413159
# 2  54.598150  1096.633158     7.389056    54.598150  148.413159

# %% [markdown]
# # Registros de Vacinação COVID19 (Acre)
#
# link: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8

# %% [markdown]
# ## Lendo CSV

# %%
vacAcre = pd.read_csv(
    'VacinacaoCovid.csv',
    sep=';')
vacAcre
# Out:
#                                       document_id  \
# 0       fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 1       fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 2       d704d5e0-db08-4864-93ff-1c49ba1c4e44-i0b0
# 3       fadbea84-381c-4e84-920c-fdd146d96744-i0b0
# 4       d60011fe-a1b4-4d34-945e-8e041d420609-i0b0
# ...                                           ...
# 390906  a204873f-c64c-4eb5-9fea-0d4ee046130e-i0b0
# 390907  a2079d4d-8b31-49eb-ba56-ed487360869f-i0b0
# 390908  a20c5001-d4af-4eb8-991b-a62c621d16c7-i0b0
# 390909  a21f33ee-cdca-455c-9ade-55a6d387c9e8-i0b0
# 390910  a22d6003-57cb-4478-8f7e-0d7869cf85a5-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       f2fcc79a2ffb7aabbe8e31cf839b846d1c4e1bb46fd042...              11
# 1       9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 2       51dfac9ce22890c86f340ae55bdd8eb0e6159f4ace007a...               4
# 3       59ea685f572ee8be8c48fef8962167a2b96ab5627613a2...              30
# 4       b26582744d70ed052c62fe4d535cdddb2a39159e39bf11...              20
# ...                                                   ...             ...
# 390906  e36501b49b123823b8d40e97702da8ad7f5bff510c1f27...              43
# 390907  891595991c37ec5ea8f70b8d59bad9af1c59007cca3315...              33
# 390908  631ee2f84ed42247316b9bfbf152960688c9975431de8a...              39
# 390909  4d7b6c768c3a44051038953ccca29ba266a210a0fcdf5f...               3
# 390910  cfa95d9e647d505582bcfb197f7bb4a45718b982fb3323...              55
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   2010-10-13                          M
# 1                   2005-06-27                          M
# 2                   2019-03-25                          M
# 3                   1993-11-30                          F
# 4                   2000-07-21                          F
# ...                        ...                        ...
# 390906              1978-06-22                          M
# 390907              1988-05-26                          F
# 390908              1982-10-22                          F
# 390909              2020-02-18                          F
# 390910              1966-06-23                          F
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                             4                AMARELA
# 1                            99         SEM INFORMACAO
# 2                             1                 BRANCA
# 3                             3                  PARDA
# 4                             2                  PRETA
# ...                         ...                    ...
# 390906                        3                  PARDA
# 390907                        3                  PARDA
# 390908                        4                AMARELA
# 390909                        3                  PARDA
# 390910                        3                  PARDA
#
#         paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                                120038.0                      10.0
# 1                                120040.0                      10.0
# 2                                120040.0                      10.0
# 3                                120040.0                      10.0
# 4                                120070.0                      10.0
# ...                                   ...                       ...
# 390906                           120040.0                      10.0
# 390907                           120038.0                      10.0
# 390908                           120013.0                      10.0
# 390909                           120005.0                      10.0
# 390910                           120040.0                      10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                  PLACIDO DE CASTRO  ...                     NaN
# 1                         RIO BRANCO  ...                     2.0
# 2                         RIO BRANCO  ...                     2.0
# 3                         RIO BRANCO  ...                    21.0
# 4                             XAPURI  ...                     6.0
# ...                              ...  ...                     ...
# 390906                    RIO BRANCO  ...                     2.0
# 390907             PLACIDO DE CASTRO  ...                     8.0
# 390908                        BUJARI  ...                     2.0
# 390909                  ASSIS BRASIL  ...                     7.0
# 390910                    RIO BRANCO  ...                     1.0
#
#                    vacina_categoria_nome  vacina_lote  \
# 0                                    NaN       210520
# 1                           Faixa Etária       FD7221
# 2                           Faixa Etária       230165
# 3                              Gestantes       230165
# 4       Povos e Comunidades Tradicionais       210012
# ...                                  ...          ...
# 390906                      Faixa Etária       FL1939
# 390907         Trabalhadores da Educação   213VCD042Z
# 390908                      Faixa Etária       FJ4187
# 390909                   Povos Indígenas       GX6964
# 390910                      Comorbidades       FF8848
#
#                      vacina_fabricante_nome  vacina_fabricante_referencia  \
# 0                          SINOVAC/BUTANTAN                         29501
# 1                                    PFIZER   Organization/00394544000851
# 2                                  BUTANTAN                           152
# 3                                  BUTANTAN                           152
# 4                          SINOVAC/BUTANTAN   Organization/61189445000156
# ...                                     ...                           ...
# 390906                               PFIZER                         28290
# 390907                  ASTRAZENECA/FIOCRUZ   Organization/33781055000135
# 390908                               PFIZER            Organization/28290
# 390909  PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                         28290
# 390910                               PFIZER            Organization/28290
#
#        vacina_dataAplicacao vacina_descricao_dose  vacina_codigo  \
# 0                2022-08-04               1ª Dose             86
# 1                2021-08-13               1ª Dose             87
# 2                2024-01-29                 Única             33
# 3                2024-03-05                 Única             33
# 4                2021-05-21               2ª Dose             86
# ...                     ...                   ...            ...
# 390906           2022-01-26               2ª Dose             87
# 390907           2021-06-17               1ª Dose             85
# 390908           2022-01-18               Reforço             87
# 390909           2023-11-24               2ª Dose            102
# 390910           2021-11-03               Reforço             87
#
#                                               vacina_nome sistema_origem
# 0                   COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 1                             COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                                                    INF3       Novo PNI
# 3                                                    INF3       Novo PNI
# 4                   COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# ...                                                   ...            ...
# 390906                        COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390907          COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 390908                        COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390909  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...       Novo PNI
# 390910                        COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [390911 rows x 32 columns]

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 1  fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 2  d704d5e0-db08-4864-93ff-1c49ba1c4e44-i0b0
# 3  fadbea84-381c-4e84-920c-fdd146d96744-i0b0
# 4  d60011fe-a1b4-4d34-945e-8e041d420609-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  f2fcc79a2ffb7aabbe8e31cf839b846d1c4e1bb46fd042...              11
# 1  9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 2  51dfac9ce22890c86f340ae55bdd8eb0e6159f4ace007a...               4
# 3  59ea685f572ee8be8c48fef8962167a2b96ab5627613a2...              30
# 4  b26582744d70ed052c62fe4d535cdddb2a39159e39bf11...              20
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2010-10-13                          M                        4
# 1              2005-06-27                          M                       99
# 2              2019-03-25                          M                        1
# 3              1993-11-30                          F                        3
# 4              2000-07-21                          F                        2
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                           120038.0
# 1         SEM INFORMACAO                           120040.0
# 2                 BRANCA                           120040.0
# 3                  PARDA                           120040.0
# 4                  PRETA                           120070.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0             PLACIDO DE CASTRO  ...
# 1                      10.0                    RIO BRANCO  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0                        XAPURI  ...
#
#   vacina_categoria_codigo             vacina_categoria_nome  vacina_lote  \
# 0                     NaN                               NaN       210520
# 1                     2.0                      Faixa Etária       FD7221
# 2                     2.0                      Faixa Etária       230165
# 3                    21.0                         Gestantes       230165
# 4                     6.0  Povos e Comunidades Tradicionais       210012
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0       SINOVAC/BUTANTAN                         29501           2022-08-04
# 1                 PFIZER   Organization/00394544000851           2021-08-13
# 2               BUTANTAN                           152           2024-01-29
# 3               BUTANTAN                           152           2024-03-05
# 4       SINOVAC/BUTANTAN   Organization/61189445000156           2021-05-21
#
#   vacina_descricao_dose  vacina_codigo                            vacina_nome  \
# 0               1ª Dose             86  COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 1               1ª Dose             87            COVID-19 PFIZER - COMIRNATY
# 2                 Única             33                                   INF3
# 3                 Única             33                                   INF3
# 4               2ª Dose             86  COVID-19 SINOVAC/BUTANTAN - CORONAVAC
#
#   sistema_origem
# 0       Novo PNI
# 1       Novo PNI
# 2       Novo PNI
# 3       Novo PNI
# 4       Novo PNI
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Verificando dataframe

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390911 entries, 0 to 390910
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               390911 non-null  object
#  1   paciente_id                               390911 non-null  object
#  2   paciente_idade                            390911 non-null  int64
#  3   paciente_dataNascimento                   390911 non-null  object
#  4   paciente_enumSexoBiologico                390911 non-null  object
#  5   paciente_racaCor_codigo                   390911 non-null  int64
#  6   paciente_racaCor_valor                    390911 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         388458 non-null  float64
#  8   paciente_endereco_coPais                  388464 non-null  float64
#  9   paciente_endereco_nmMunicipio             388463 non-null  object
#  10  paciente_endereco_nmPais                  388464 non-null  object
#  11  paciente_endereco_uf                      388458 non-null  object
#  12  paciente_endereco_cep                     333695 non-null  float64
#  13  paciente_nacionalidade_enumNacionalidade  390732 non-null  object
#  14  estabelecimento_valor                     390911 non-null  int64
#  15  estabelecimento_razaoSocial               390911 non-null  object
#  16  estalecimento_noFantasia                  390911 non-null  object
#  17  estabelecimento_municipio_codigo          390911 non-null  int64
#  18  estabelecimento_municipio_nome            390911 non-null  object
#  19  estabelecimento_uf                        390911 non-null  object
#  20  vacina_grupoAtendimento_codigo            390911 non-null  int64
#  21  vacina_grupoAtendimento_nome              389567 non-null  object
#  22  vacina_categoria_codigo                   370178 non-null  float64
#  23  vacina_categoria_nome                     370178 non-null  object
#  24  vacina_lote                               390911 non-null  object
#  25  vacina_fabricante_nome                    390911 non-null  object
#  26  vacina_fabricante_referencia              385633 non-null  object
#  27  vacina_dataAplicacao                      390911 non-null  object
#  28  vacina_descricao_dose                     390911 non-null  object
#  29  vacina_codigo                             390911 non-null  int64
#  30  vacina_nome                               390902 non-null  object
#  31  sistema_origem                            390512 non-null  object
# dtypes: float64(4), int64(6), object(22)
# memory usage: 95.4+ MB

# %% [markdown]
# ## Copiando parte do dataframe

# %%
vacAcre_copy = vacAcre[:20000].copy()
vacAcre_copy
# Out:
#                                      document_id  \
# 0      fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 1      fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 2      d704d5e0-db08-4864-93ff-1c49ba1c4e44-i0b0
# 3      fadbea84-381c-4e84-920c-fdd146d96744-i0b0
# 4      d60011fe-a1b4-4d34-945e-8e041d420609-i0b0
# ...                                          ...
# 19995  97c2febb-f881-41a8-a028-5ba6f136e371-i0b0
# 19996  08496361-1d02-4f7a-b443-e1a7a894cb3b-i0b0
# 19997  1de72f99-157f-448d-a829-2e0d0df7b106-i0b0
# 19998  627e5fc8-bd23-46be-b9df-1a3c3deb15cf-i0b0
# 19999  62643f6f-c5e4-49fd-b694-92651c2a973b-i0b0
#
#                                              paciente_id  paciente_idade  \
# 0      f2fcc79a2ffb7aabbe8e31cf839b846d1c4e1bb46fd042...              11
# 1      9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 2      51dfac9ce22890c86f340ae55bdd8eb0e6159f4ace007a...               4
# 3      59ea685f572ee8be8c48fef8962167a2b96ab5627613a2...              30
# 4      b26582744d70ed052c62fe4d535cdddb2a39159e39bf11...              20
# ...                                                  ...             ...
# 19995  8d6e5421949aac9706b9dfd564bf11d11e6c846de8fe70...              77
# 19996  42915c709bc63036d6195bc86d71a764257451d9e94e4e...              46
# 19997  ae31bdac0057dad2452853527ec0e2c9f75df2b87f4605...              28
# 19998  8a399daec79e9d95e8e8d63d0ce8c32dd74fc506b1ffbf...              34
# 19999  d6bd7f4b62251bf25b2e59154ed650c8fa3d41470faaa5...              48
#
#       paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                  2010-10-13                          M
# 1                  2005-06-27                          M
# 2                  2019-03-25                          M
# 3                  1993-11-30                          F
# 4                  2000-07-21                          F
# ...                       ...                        ...
# 19995              1944-09-23                          M
# 19996              1975-05-17                          F
# 19997              1994-08-18                          M
# 19998              1986-12-19                          M
# 19999              1973-04-04                          M
#
#        paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                            4                AMARELA
# 1                           99         SEM INFORMACAO
# 2                            1                 BRANCA
# 3                            3                  PARDA
# 4                            2                  PRETA
# ...                        ...                    ...
# 19995                        4                AMARELA
# 19996                        3                  PARDA
# 19997                        1                 BRANCA
# 19998                        3                  PARDA
# 19999                        1                 BRANCA
#
#        paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                               120038.0                      10.0
# 1                               120040.0                      10.0
# 2                               120040.0                      10.0
# 3                               120040.0                      10.0
# 4                               120070.0                      10.0
# ...                                  ...                       ...
# 19995                           120060.0                      10.0
# 19996                           120040.0                      10.0
# 19997                           120038.0                      10.0
# 19998                           120040.0                      10.0
# 19999                           120040.0                      10.0
#
#       paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                 PLACIDO DE CASTRO  ...                     NaN
# 1                        RIO BRANCO  ...                     2.0
# 2                        RIO BRANCO  ...                     2.0
# 3                        RIO BRANCO  ...                    21.0
# 4                            XAPURI  ...                     6.0
# ...                             ...  ...                     ...
# 19995                      TARAUACA  ...                     2.0
# 19996                    RIO BRANCO  ...                     2.0
# 19997             PLACIDO DE CASTRO  ...                     2.0
# 19998                    RIO BRANCO  ...                     2.0
# 19999                    RIO BRANCO  ...                    10.0
#
#                   vacina_categoria_nome  vacina_lote vacina_fabricante_nome  \
# 0                                   NaN       210520       SINOVAC/BUTANTAN
# 1                          Faixa Etária       FD7221                 PFIZER
# 2                          Faixa Etária       230165               BUTANTAN
# 3                             Gestantes       230165               BUTANTAN
# 4      Povos e Comunidades Tradicionais       210012       SINOVAC/BUTANTAN
# ...                                 ...          ...                    ...
# 19995                      Faixa Etária      212J21A                JANSSEN
# 19996                      Faixa Etária   216VCD213W    ASTRAZENECA/FIOCRUZ
# 19997                      Faixa Etária   21PVCD389W    ASTRAZENECA/FIOCRUZ
# 19998                      Faixa Etária       FA9090                 PFIZER
# 19999       Trabalhadores de Transporte   215VCD134Z    ASTRAZENECA/FIOCRUZ
#
#        vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                             29501           2022-08-04
# 1       Organization/00394544000851           2021-08-13
# 2                               152           2024-01-29
# 3                               152           2024-03-05
# 4       Organization/61189445000156           2021-05-21
# ...                             ...                  ...
# 19995                         30587           2022-07-22
# 19996   Organization/33781055000135           2021-08-09
# 19997                           149           2022-08-20
# 19998   Organization/00394544000851           2021-07-02
# 19999   Organization/33781055000135           2021-07-28
#
#       vacina_descricao_dose  vacina_codigo  \
# 0                   1ª Dose             86
# 1                   1ª Dose             87
# 2                     Única             33
# 3                     Única             33
# 4                   2ª Dose             86
# ...                     ...            ...
# 19995               Reforço             88
# 19996               2ª Dose             85
# 19997            2º Reforço             85
# 19998               1ª Dose             87
# 19999               2ª Dose             85
#
#                                      vacina_nome sistema_origem
# 0          COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 1                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                                           INF3       Novo PNI
# 3                                           INF3       Novo PNI
# 4          COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# ...                                          ...            ...
# 19995             COVID-19 JANSSEN - Ad26.COV2.S       Novo PNI
# 19996  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 19997  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 19998                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19999  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [20000 rows x 32 columns]

# %% [markdown]
# ## Qual o percentual das vacinas aplicadas foram na capital???

# %%
vacAcre_copy['fl_capital'] = 0

# %%
vacAcre_copy.head(2)
# Out:
#                                  document_id  \
# 0  fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 1  fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  f2fcc79a2ffb7aabbe8e31cf839b846d1c4e1bb46fd042...              11
# 1  9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2010-10-13                          M                        4
# 1              2005-06-27                          M                       99
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                           120038.0
# 1         SEM INFORMACAO                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0             PLACIDO DE CASTRO  ...
# 1                      10.0                    RIO BRANCO  ...
#
#   vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 0                   NaN      210520        SINOVAC/BUTANTAN
# 1          Faixa Etária      FD7221                  PFIZER
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0                        29501            2022-08-04               1ª Dose
# 1  Organization/00394544000851            2021-08-13               1ª Dose
#
#   vacina_codigo                            vacina_nome sistema_origem  \
# 0            86  COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 1            87            COVID-19 PFIZER - COMIRNATY       Novo PNI
#
#   fl_capital
# 0          0
# 1          0
#
# [2 rows x 33 columns]

# %%
vacAcre_copy.loc[vacAcre_copy['paciente_endereco_nmMunicipio'] == 'RIO BRANCO', 'fl_capital'] = 1

# %%
vacAcre_copy.head(10)
# Out:
#                                  document_id  \
# 0  fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 1  fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 2  d704d5e0-db08-4864-93ff-1c49ba1c4e44-i0b0
# 3  fadbea84-381c-4e84-920c-fdd146d96744-i0b0
# 4  d60011fe-a1b4-4d34-945e-8e041d420609-i0b0
# 5  fadc47ac-c9aa-4d01-882e-b2b4784df27e-i0b0
# 6  fdceed25-e60f-4635-9fe0-07f107916153-i0b0
# 7  fb1af672-18a5-4073-9012-0da85e40046f-i0b0
# 8  a216cca5-6070-4165-8158-4c5ca10086ea-i0b0
# 9  fb2d6b76-65a5-4909-a2a6-adc66e20bc72-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  f2fcc79a2ffb7aabbe8e31cf839b846d1c4e1bb46fd042...              11
# 1  9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 2  51dfac9ce22890c86f340ae55bdd8eb0e6159f4ace007a...               4
# 3  59ea685f572ee8be8c48fef8962167a2b96ab5627613a2...              30
# 4  b26582744d70ed052c62fe4d535cdddb2a39159e39bf11...              20
# 5  a7d8ebad17d6450189de7dbc681dd4970dd4241c77032a...              44
# 6  38e9546044dc852ffe5a450f463131beb05b5e077e5324...              60
# 7  78388cd7636f20e7cbcea0d83f76c0dfe8a448e8cc13cf...              62
# 8  b4836e8a89e2b94e54a38a65bed6046e18e4ebfa054ade...              56
# 9  8ef44d37b907a8674812ac82a81f82b205abfea21d9500...              37
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2010-10-13                          M                        4
# 1              2005-06-27                          M                       99
# 2              2019-03-25                          M                        1
# 3              1993-11-30                          F                        3
# 4              2000-07-21                          F                        2
# 5              1977-06-23                          F                        3
# 6              1960-11-02                          F                        4
# 7              1959-01-01                          F                       99
# 8              1966-04-14                          F                        4
# 9              1983-09-28                          M                        3
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                           120038.0
# 1         SEM INFORMACAO                           120040.0
# 2                 BRANCA                           120040.0
# 3                  PARDA                           120040.0
# 4                  PRETA                           120070.0
# 5                  PARDA                           120040.0
# 6                AMARELA                           120040.0
# 7         SEM INFORMACAO                           120040.0
# 8                AMARELA                           120070.0
# 9                  PARDA                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0             PLACIDO DE CASTRO  ...
# 1                      10.0                    RIO BRANCO  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0                        XAPURI  ...
# 5                      10.0                    RIO BRANCO  ...
# 6                      10.0                    RIO BRANCO  ...
# 7                      10.0                    RIO BRANCO  ...
# 8                      10.0                        XAPURI  ...
# 9                      10.0                    RIO BRANCO  ...
#
#               vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 0                               NaN      210520        SINOVAC/BUTANTAN
# 1                      Faixa Etária      FD7221                  PFIZER
# 2                      Faixa Etária      230165                BUTANTAN
# 3                         Gestantes      230165                BUTANTAN
# 4  Povos e Comunidades Tradicionais      210012        SINOVAC/BUTANTAN
# 5                      Faixa Etária      FL1939                  PFIZER
# 6                      Faixa Etária  216VCD182W     ASTRAZENECA/FIOCRUZ
# 7                      Faixa Etária      210110        SINOVAC/BUTANTAN
# 8                      Faixa Etária      202001                  PFIZER
# 9                      Faixa Etária     208A21A                 JANSSEN
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0                        29501            2022-08-04               1ª Dose
# 1  Organization/00394544000851            2021-08-13               1ª Dose
# 2                          152            2024-01-29                 Única
# 3                          152            2024-03-05                 Única
# 4  Organization/61189445000156            2021-05-21               2ª Dose
# 5           Organization/28290            2021-12-29               Reforço
# 6  Organization/33781055000135            2021-07-29               2ª Dose
# 7  Organization/61189445000156            2021-04-28               2ª Dose
# 8                        28290            2022-09-24               Reforço
# 9  Organization/00394544000851            2021-06-28                  Dose
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 1            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2            33                                       INF3       Novo PNI
# 3            33                                       INF3       Novo PNI
# 4            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 5            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 6            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 7            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 8            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 9            88             COVID-19 JANSSEN - Ad26.COV2.S       Novo PNI
#
#   fl_capital
# 0          0
# 1          1
# 2          1
# 3          1
# 4          0
# 5          1
# 6          1
# 7          1
# 8          0
# 9          1
#
# [10 rows x 33 columns]

# %%
vacAcre_copy[['paciente_endereco_nmMunicipio','fl_capital']]
# Out:
#       paciente_endereco_nmMunicipio  fl_capital
# 0                 PLACIDO DE CASTRO           0
# 1                        RIO BRANCO           1
# 2                        RIO BRANCO           1
# 3                        RIO BRANCO           1
# 4                            XAPURI           0
# ...                             ...         ...
# 19995                      TARAUACA           0
# 19996                    RIO BRANCO           1
# 19997             PLACIDO DE CASTRO           0
# 19998                    RIO BRANCO           1
# 19999                    RIO BRANCO           1
#
# [20000 rows x 2 columns]

# %%
vacAcre_copy['fl_capital'].sum()
# Out:
# np.int64(9725)

# %%
(9294/20000) * 100
# Out:
# 46.47

# %% [markdown]
# ## Qual a idade média dos pacientes???

# %%
vacAcre_copy['paciente_idade'].mean()
# Out:
# np.float64(35.656)
