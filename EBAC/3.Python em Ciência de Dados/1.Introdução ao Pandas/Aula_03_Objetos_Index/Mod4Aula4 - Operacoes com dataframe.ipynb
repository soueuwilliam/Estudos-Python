# %%
import numpy  as np
import pandas as pd

# %% [markdown]
# # Operações com ``DataFrame``

# %% [markdown]
# ## Criando 2 dataframes (3 x 5)

# %%
np.random.randint(10, size=(3, 5))
# Out:
# array([[4, 6, 1, 1, 6],
#        [6, 5, 2, 3, 4],
#        [6, 6, 4, 8, 9]], dtype=int32)

# %%
df1 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df1
# Out:
#    A  B  C  D  E
# 0  2  3  7  7  5
# 1  3  1  4  1  5
# 2  4  7  2  4  5

# %%
df2 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df2
# Out:
#    A  B  C  D  E
# 0  1  9  0  2  3
# 1  5  7  6  1  0
# 2  4  0  1  1  8

# %% [markdown]
# ## Somando 2 dataframes (3 x 5)

# %%
df1 + df2
# Out:
#    A   B   C   D   E
# 0  2  17  14  17   8
# 1  9   2   8   8  13
# 2  7  12   8   8   6

# %% [markdown]
# ## Criando 1 dataframe (1 x 5)

# %%
df3 = pd.DataFrame(np.random.randint(10, size=(1, 5)), columns=['A','B','C','D','E'])
df3
# Out:
#    A  B  C  D  E
# 0  2  4  0  5  8

# %% [markdown]
# ## Somando 2 dataframes (3 x 5 e 1 x 5)

# %%
df1 + df3
# Out:
#      A     B    C    D    E
# 0  8.0  14.0  8.0  8.0  3.0
# 1  NaN   NaN  NaN  NaN  NaN
# 2  NaN   NaN  NaN  NaN  NaN

# %% [markdown]
# ## Zerando uma linha

# %%
df1
# Out:
#    A  B  C  D  E
# 0  1  8  7  8  2
# 1  4  2  8  8  5
# 2  7  5  7  1  6

# %%
df1.iloc[0]
# Out:
# A    1
# B    8
# C    7
# D    8
# E    2
# Name: 0, dtype: int32

# %%
df1 - df1.iloc[0]
# Out:
#    A  B  C  D  E
# 0  0  0  0  0  0
# 1  3 -6  1  0  3
# 2  6 -3  0 -7  4

# %% [markdown]
# ## Operação com escalar

# %%
df1
# Out:
#    A  B  C  D  E
# 0  2  3  7  7  5
# 1  3  1  4  1  5
# 2  4  7  2  4  5

# %%
df1 * 100
# Out:
#      A    B    C    D    E
# 0  200  300  700  700  500
# 1  300  100  400  100  500
# 2  400  700  200  400  500

# %%
df1 * 100 + 200
# Out:
#      A    B    C     D     E
# 0  700  300  600   200   500
# 1  600  900  200  1000  1000
# 2  900  900  900   200   700

# %% [markdown]
# ## Transpondo df

# %%
df1
# Out:
#    A  B  C  D  E
# 0  2  3  7  7  5
# 1  3  1  4  1  5
# 2  4  7  2  4  5

# %%
df1.T
# Out:
#    0  1  2
# A  2  3  4
# B  3  1  7
# C  7  4  2
# D  7  1  4
# E  5  5  5

# %% [markdown]
# ## Calculando exponencial dos valores

# %%
np.exp(df1)
# Out:
#            A            B            C            D           E
# 0   7.389056    20.085537  1096.633158  1096.633158  148.413159
# 1  20.085537     2.718282    54.598150     2.718282  148.413159
# 2  54.598150  1096.633158     7.389056    54.598150  148.413159

# %% [markdown]
# # Registros de Vacinação COVID19 (Acre)
#
# link: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8

# %% [markdown]
# ## Lendo CSV

# %%
vacAcre = pd.read_csv(
    'VacinacaoCovid.csv',
    sep=';')
vacAcre
# Out:
#                                       document_id  \
# 0       7bd14950-ef22-46aa-b6f3-a3771d407164-i0b0
# 1       932c2b71-da1b-4cc9-9243-45876fa33afc-i0b0
# 2       16f541ba-6609-4227-8347-9240e13ae1f4-i0b0
# 3       934f1ef2-407a-4d2a-9c50-6e3b1fadeaaf-i0b0
# 4       39909dc5-51c1-4ae9-b8a1-17f7fe6f7828-i0b0
# ...                                           ...
# 390906  5041e7e0-2659-4819-b10e-97fb3738f4d9-i0b0
# 390907  50aacf36-c2d8-4c17-a2f6-6f18f0c8fd97-i0b0
# 390908  50e209a1-eca4-4669-bfc4-f7d679ad8d4b-i0b0
# 390909  51a96d31-7824-44c6-8ab7-7f8e62de321f-i0b0
# 390910  51e3795a-3075-4945-b42b-6ce0552e8243-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       c1c450a18a82f9213f7306f05e8e41b77ef5f2ee8e489a...              66
# 1       f9f8a69f428be82064cbb83644dda18ef14085b416ec40...              16
# 2       37c352eb7fd28c5c7f7bbe97f342326dd37a37e9c0ad02...              36
# 3       0506ec80187b517616f1cf40bc5f092038190712af1e6f...              20
# 4       6f3d86e9e26107ad3f6e6fb3e40fe567b84703e83df4cc...              10
# ...                                                   ...             ...
# 390906  f7ca857e51f11dd8cc2e0ca51e469834190ecd90f4f27e...              32
# 390907  992efecfb59a75eca20fa99e2383970d61b0b885766fba...              22
# 390908  52dc30b0eb70375f9623b42f4839451fa6ce3504e0ac44...              13
# 390909  8e8251f4497c8fc41381a7a463a08f7561ceb26207e6f3...              25
# 390910  66a80435ae5362eed6e78a2d3336db99dd036da86f7afa...              45
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   1955-09-18                          F
# 1                   2005-04-22                          F
# 2                   1985-05-22                          F
# 3                   2001-11-11                          M
# 4                   2011-10-16                          F
# ...                        ...                        ...
# 390906              1989-09-09                          F
# 390907              1999-05-05                          F
# 390908              2008-06-05                          F
# 390909              1998-06-20                          F
# 390910              1976-10-14                          M
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                            99         SEM INFORMACAO
# 1                             3                  PARDA
# 2                             4                AMARELA
# 3                             3                  PARDA
# 4                             3                  PARDA
# ...                         ...                    ...
# 390906                        3                  PARDA
# 390907                       99         SEM INFORMACAO
# 390908                        4                AMARELA
# 390909                       99         SEM INFORMACAO
# 390910                        3                  PARDA
#
#         paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                                120040.0                      10.0
# 1                                120010.0                      10.0
# 2                                120040.0                      10.0
# 3                                120040.0                      10.0
# 4                                120040.0                      10.0
# ...                                   ...                       ...
# 390906                           120040.0                      10.0
# 390907                           120040.0                      10.0
# 390908                           120040.0                      10.0
# 390909                           120030.0                      10.0
# 390910                           120040.0                      10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                         RIO BRANCO  ...                     9.0
# 1                          BRASILEIA  ...                   114.0
# 2                         RIO BRANCO  ...                     2.0
# 3                         RIO BRANCO  ...                     2.0
# 4                         RIO BRANCO  ...                     NaN
# ...                              ...  ...                     ...
# 390906                    RIO BRANCO  ...                     2.0
# 390907                    RIO BRANCO  ...                     1.0
# 390908                    RIO BRANCO  ...                     2.0
# 390909                         FEIJO  ...                     7.0
# 390910                    RIO BRANCO  ...                     2.0
#
#          vacina_categoria_nome  vacina_lote  vacina_fabricante_nome  \
# 0       Trabalhadores de Saúde   21OVCD317W     ASTRAZENECA/FIOCRUZ
# 1                       Outros       FF8842                  PFIZER
# 2                 Faixa Etária       FA9096                  PFIZER
# 3                 Faixa Etária      32010BD                  PFIZER
# 4                          NaN       FP8290  Pendente Identificação
# ...                        ...          ...                     ...
# 390906            Faixa Etária       FF8848                  PFIZER
# 390907            Comorbidades       FJ4187                  PFIZER
# 390908            Faixa Etária       FA9096                  PFIZER
# 390909         Povos Indígenas       GJ9239                  PFIZER
# 390910            Faixa Etária       FL1939                  PFIZER
#
#         vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                                149           2022-07-06
# 1        Organization/00394544000851           2021-10-13
# 2        Organization/00394544000851           2021-07-27
# 3                 Organization/28290           2021-12-17
# 4                 Organization/28290           2022-02-17
# ...                              ...                  ...
# 390906            Organization/28290           2022-02-11
# 390907            Organization/28290           2022-01-17
# 390908   Organization/00394544000851           2021-08-12
# 390909                         28290           2024-01-25
# 390910            Organization/28290           2022-01-04
#
#        vacina_descricao_dose  vacina_codigo  \
# 0                 2º Reforço             85
# 1                    2ª Dose             87
# 2                    1ª Dose             87
# 3                    2ª Dose             87
# 4                    1ª Dose             99
# ...                      ...            ...
# 390906               Reforço             87
# 390907               Reforço             87
# 390908               1ª Dose             87
# 390909               Reforço            103
# 390910               2ª Dose             87
#
#                                       vacina_nome sistema_origem
# 0       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4          COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# ...                                           ...            ...
# 390906                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390907                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390908                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390909      COVID-19 PFIZER - COMIRNATY BIVALENTE       Novo PNI
# 390910                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [390911 rows x 32 columns]

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  7bd14950-ef22-46aa-b6f3-a3771d407164-i0b0
# 1  932c2b71-da1b-4cc9-9243-45876fa33afc-i0b0
# 2  16f541ba-6609-4227-8347-9240e13ae1f4-i0b0
# 3  934f1ef2-407a-4d2a-9c50-6e3b1fadeaaf-i0b0
# 4  39909dc5-51c1-4ae9-b8a1-17f7fe6f7828-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  c1c450a18a82f9213f7306f05e8e41b77ef5f2ee8e489a...              66
# 1  f9f8a69f428be82064cbb83644dda18ef14085b416ec40...              16
# 2  37c352eb7fd28c5c7f7bbe97f342326dd37a37e9c0ad02...              36
# 3  0506ec80187b517616f1cf40bc5f092038190712af1e6f...              20
# 4  6f3d86e9e26107ad3f6e6fb3e40fe567b84703e83df4cc...              10
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1955-09-18                          F                       99
# 1              2005-04-22                          F                        3
# 2              1985-05-22                          F                        4
# 3              2001-11-11                          M                        3
# 4              2011-10-16                          F                        3
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                           120040.0
# 1                  PARDA                           120010.0
# 2                AMARELA                           120040.0
# 3                  PARDA                           120040.0
# 4                  PARDA                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                     BRASILEIA  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0                    RIO BRANCO  ...
#
#   vacina_categoria_codigo   vacina_categoria_nome  vacina_lote  \
# 0                     9.0  Trabalhadores de Saúde   21OVCD317W
# 1                   114.0                  Outros       FF8842
# 2                     2.0            Faixa Etária       FA9096
# 3                     2.0            Faixa Etária      32010BD
# 4                     NaN                     NaN       FP8290
#
#    vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0     ASTRAZENECA/FIOCRUZ                           149           2022-07-06
# 1                  PFIZER   Organization/00394544000851           2021-10-13
# 2                  PFIZER   Organization/00394544000851           2021-07-27
# 3                  PFIZER            Organization/28290           2021-12-17
# 4  Pendente Identificação            Organization/28290           2022-02-17
#
#   vacina_descricao_dose  vacina_codigo  \
# 0            2º Reforço             85
# 1               2ª Dose             87
# 2               1ª Dose             87
# 3               2ª Dose             87
# 4               1ª Dose             99
#
#                                  vacina_nome sistema_origem
# 0  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Verificando dataframe

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390911 entries, 0 to 390910
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               390911 non-null  object
#  1   paciente_id                               390911 non-null  object
#  2   paciente_idade                            390911 non-null  int64
#  3   paciente_dataNascimento                   390911 non-null  object
#  4   paciente_enumSexoBiologico                390911 non-null  object
#  5   paciente_racaCor_codigo                   390911 non-null  int64
#  6   paciente_racaCor_valor                    390911 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         388458 non-null  float64
#  8   paciente_endereco_coPais                  388464 non-null  float64
#  9   paciente_endereco_nmMunicipio             388463 non-null  object
#  10  paciente_endereco_nmPais                  388464 non-null  object
#  11  paciente_endereco_uf                      388458 non-null  object
#  12  paciente_endereco_cep                     333695 non-null  float64
#  13  paciente_nacionalidade_enumNacionalidade  390732 non-null  object
#  14  estabelecimento_valor                     390911 non-null  int64
#  15  estabelecimento_razaoSocial               390911 non-null  object
#  16  estalecimento_noFantasia                  390911 non-null  object
#  17  estabelecimento_municipio_codigo          390911 non-null  int64
#  18  estabelecimento_municipio_nome            390911 non-null  object
#  19  estabelecimento_uf                        390911 non-null  object
#  20  vacina_grupoAtendimento_codigo            390911 non-null  int64
#  21  vacina_grupoAtendimento_nome              389567 non-null  object
#  22  vacina_categoria_codigo                   370178 non-null  float64
#  23  vacina_categoria_nome                     370178 non-null  object
#  24  vacina_lote                               390911 non-null  object
#  25  vacina_fabricante_nome                    390911 non-null  object
#  26  vacina_fabricante_referencia              385633 non-null  object
#  27  vacina_dataAplicacao                      390911 non-null  object
#  28  vacina_descricao_dose                     390911 non-null  object
#  29  vacina_codigo                             390911 non-null  int64
#  30  vacina_nome                               390902 non-null  object
#  31  sistema_origem                            390512 non-null  object
# dtypes: float64(4), int64(6), object(22)
# memory usage: 95.4+ MB

# %% [markdown]
# ## Copiando parte do dataframe

# %%
vacAcre_copy = vacAcre[:20000].copy()
vacAcre_copy
# Out:
#                                      document_id  \
# 0      7bd14950-ef22-46aa-b6f3-a3771d407164-i0b0
# 1      932c2b71-da1b-4cc9-9243-45876fa33afc-i0b0
# 2      16f541ba-6609-4227-8347-9240e13ae1f4-i0b0
# 3      934f1ef2-407a-4d2a-9c50-6e3b1fadeaaf-i0b0
# 4      39909dc5-51c1-4ae9-b8a1-17f7fe6f7828-i0b0
# ...                                          ...
# 19995  74aabbd9-f5f9-4b33-b4f5-fc144e838bc5-i0b0
# 19996  2acb5bca-c8c3-470e-aa56-c9b6668e9341-i0b0
# 19997  33b99bf2-a171-4e0e-a119-dc52da998848-i0b0
# 19998  2aee1266-506a-474a-983f-031127fb82bb-i0b0
# 19999  7730f8a1-fdc2-4d33-a761-e9a63fec2f9f-i0b0
#
#                                              paciente_id  paciente_idade  \
# 0      c1c450a18a82f9213f7306f05e8e41b77ef5f2ee8e489a...              66
# 1      f9f8a69f428be82064cbb83644dda18ef14085b416ec40...              16
# 2      37c352eb7fd28c5c7f7bbe97f342326dd37a37e9c0ad02...              36
# 3      0506ec80187b517616f1cf40bc5f092038190712af1e6f...              20
# 4      6f3d86e9e26107ad3f6e6fb3e40fe567b84703e83df4cc...              10
# ...                                                  ...             ...
# 19995  eef82dad9e59f042ef0c98b043fe8c4f6ec26b24a0e95c...              24
# 19996  cf3ddb5229cffb9287494cdf2d214146af497d9a881db3...              44
# 19997  5d5f42002f2b2106e4f8598701fa6b539852e189346ae3...              70
# 19998  2b6dd79bd7167c612998d31356ed47311cb9ddb9be230d...              48
# 19999  43723afc611c7b98336104859a00b6bb62a45f5218d19d...              65
#
#       paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                  1955-09-18                          F
# 1                  2005-04-22                          F
# 2                  1985-05-22                          F
# 3                  2001-11-11                          M
# 4                  2011-10-16                          F
# ...                       ...                        ...
# 19995              1998-06-26                          F
# 19996              1976-11-05                          M
# 19997              1952-02-04                          M
# 19998              1972-11-06                          F
# 19999              1955-07-09                          F
#
#        paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                           99         SEM INFORMACAO
# 1                            3                  PARDA
# 2                            4                AMARELA
# 3                            3                  PARDA
# 4                            3                  PARDA
# ...                        ...                    ...
# 19995                        3                  PARDA
# 19996                        3                  PARDA
# 19997                        1                 BRANCA
# 19998                        4                AMARELA
# 19999                        4                AMARELA
#
#        paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                               120040.0                      10.0
# 1                               120010.0                      10.0
# 2                               120040.0                      10.0
# 3                               120040.0                      10.0
# 4                               120040.0                      10.0
# ...                                  ...                       ...
# 19995                           120040.0                      10.0
# 19996                           120040.0                      10.0
# 19997                           120017.0                      10.0
# 19998                           120040.0                      10.0
# 19999                           120001.0                      10.0
#
#       paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                        RIO BRANCO  ...                     9.0
# 1                         BRASILEIA  ...                   114.0
# 2                        RIO BRANCO  ...                     2.0
# 3                        RIO BRANCO  ...                     2.0
# 4                        RIO BRANCO  ...                     NaN
# ...                             ...  ...                     ...
# 19995                    RIO BRANCO  ...                     2.0
# 19996                    RIO BRANCO  ...                     2.0
# 19997                      CAPIXABA  ...                     2.0
# 19998                    RIO BRANCO  ...                     2.0
# 19999                    ACRELANDIA  ...                     2.0
#
#         vacina_categoria_nome  vacina_lote  vacina_fabricante_nome  \
# 0      Trabalhadores de Saúde   21OVCD317W     ASTRAZENECA/FIOCRUZ
# 1                      Outros       FF8842                  PFIZER
# 2                Faixa Etária       FA9096                  PFIZER
# 3                Faixa Etária      32010BD                  PFIZER
# 4                         NaN       FP8290  Pendente Identificação
# ...                       ...          ...                     ...
# 19995            Faixa Etária   223VCD067W     ASTRAZENECA/FIOCRUZ
# 19996            Faixa Etária   215VCD116W     ASTRAZENECA/FIOCRUZ
# 19997            Faixa Etária      205F21A                 JANSSEN
# 19998            Faixa Etária       210112             ASTRAZENECA
# 19999            Faixa Etária   214VCD053W     ASTRAZENECA/FIOCRUZ
#
#        vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                               149           2022-07-06
# 1       Organization/00394544000851           2021-10-13
# 2       Organization/00394544000851           2021-07-27
# 3                Organization/28290           2021-12-17
# 4                Organization/28290           2022-02-17
# ...                             ...                  ...
# 19995                           149           2022-11-25
# 19996   Organization/33781055000135           2021-06-18
# 19997            Organization/30587           2022-06-08
# 19998   Organization/00394544000851           2021-08-31
# 19999   Organization/33781055000135           2021-06-23
#
#       vacina_descricao_dose  vacina_codigo  \
# 0                2º Reforço             85
# 1                   2ª Dose             87
# 2                   1ª Dose             87
# 3                   2ª Dose             87
# 4                   1ª Dose             99
# ...                     ...            ...
# 19995            2º Reforço             85
# 19996               1ª Dose             85
# 19997            2º Reforço             88
# 19998               2ª Dose             89
# 19999               2ª Dose             85
#
#                                      vacina_nome sistema_origem
# 0      COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4         COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# ...                                          ...            ...
# 19995  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 19996  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 19997             COVID-19 JANSSEN - Ad26.COV2.S       Novo PNI
# 19998           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 19999  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [20000 rows x 32 columns]

# %% [markdown]
# ## Qual o percentual das vacinas aplicadas foram na capital???

# %%
vacAcre_copy['fl_capital'] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 vacAcre_copy['fl_capital'] = 0
#
# NameError: name 'vacAcre_copy' is not defined

# %%
vacAcre_copy.head(2)
# Out:
#                                  document_id  \
# 0  7bd14950-ef22-46aa-b6f3-a3771d407164-i0b0
# 1  932c2b71-da1b-4cc9-9243-45876fa33afc-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  c1c450a18a82f9213f7306f05e8e41b77ef5f2ee8e489a...              66
# 1  f9f8a69f428be82064cbb83644dda18ef14085b416ec40...              16
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1955-09-18                          F                       99
# 1              2005-04-22                          F                        3
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                           120040.0
# 1                  PARDA                           120010.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                     BRASILEIA  ...
#
#     vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 0  Trabalhadores de Saúde  21OVCD317W     ASTRAZENECA/FIOCRUZ
# 1                  Outros      FF8842                  PFIZER
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0                          149            2022-07-06            2º Reforço
# 1  Organization/00394544000851            2021-10-13               2ª Dose
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
#   fl_capital
# 0          0
# 1          0
#
# [2 rows x 33 columns]

# %%
vacAcre_copy.loc[vacAcre_copy['paciente_endereco_nmMunicipio'] == 'RIO BRANCO', 'fl_capital'] = 1

# %%
vacAcre_copy.head(10)
# Out:
#                                  document_id  \
# 0  7bd14950-ef22-46aa-b6f3-a3771d407164-i0b0
# 1  932c2b71-da1b-4cc9-9243-45876fa33afc-i0b0
# 2  16f541ba-6609-4227-8347-9240e13ae1f4-i0b0
# 3  934f1ef2-407a-4d2a-9c50-6e3b1fadeaaf-i0b0
# 4  39909dc5-51c1-4ae9-b8a1-17f7fe6f7828-i0b0
# 5  936842c0-d6ca-414c-b320-e1a9510ea78d-i0b0
# 6  938f7cc8-6074-4238-ab18-56000994ca8b-i0b0
# 7  93949545-5178-416a-9c85-fe976f90d282-i0b0
# 8  4f96036d-93bc-4b40-a84b-498df7d86aee-i0b0
# 9  939c527c-7d75-4a60-95b6-ab7dd14d0fcb-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  c1c450a18a82f9213f7306f05e8e41b77ef5f2ee8e489a...              66
# 1  f9f8a69f428be82064cbb83644dda18ef14085b416ec40...              16
# 2  37c352eb7fd28c5c7f7bbe97f342326dd37a37e9c0ad02...              36
# 3  0506ec80187b517616f1cf40bc5f092038190712af1e6f...              20
# 4  6f3d86e9e26107ad3f6e6fb3e40fe567b84703e83df4cc...              10
# 5  862c62c24d12822a0765b36a3e75d93c1bac74aff3395b...              55
# 6  d2d2f8bfb27b76825287547724dc2dd401c835af95ca10...              41
# 7  2017c85688ffeb6556d20ca66f4c89bd6c832f6541ee83...              71
# 8  b21c03af1f2aabc2da715e301228b3819de95c61aba7db...              64
# 9  320e74cbbce1962bcfdc7fc97efd3c7d1244e2eae82f72...              71
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1955-09-18                          F                       99
# 1              2005-04-22                          F                        3
# 2              1985-05-22                          F                        4
# 3              2001-11-11                          M                        3
# 4              2011-10-16                          F                        3
# 5              1966-05-04                          M                        4
# 6              1980-10-17                          M                        4
# 7              1950-01-21                          M                        3
# 8              1956-11-06                          M                        3
# 9              1950-02-10                          F                        3
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                           120040.0
# 1                  PARDA                           120010.0
# 2                AMARELA                           120040.0
# 3                  PARDA                           120040.0
# 4                  PARDA                           120040.0
# 5                AMARELA                           120040.0
# 6                AMARELA                           120040.0
# 7                  PARDA                           315765.0
# 8                  PARDA                           120038.0
# 9                  PARDA                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                     BRASILEIA  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0                    RIO BRANCO  ...
# 5                      10.0                    RIO BRANCO  ...
# 6                      10.0                    RIO BRANCO  ...
# 7                      10.0         SANTA HELENA DE MINAS  ...
# 8                      10.0             PLACIDO DE CASTRO  ...
# 9                      10.0                    RIO BRANCO  ...
#
#        vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 0     Trabalhadores de Saúde  21OVCD317W     ASTRAZENECA/FIOCRUZ
# 1                     Outros      FF8842                  PFIZER
# 2               Faixa Etária      FA9096                  PFIZER
# 3               Faixa Etária     32010BD                  PFIZER
# 4                        NaN      FP8290  Pendente Identificação
# 5  Trabalhadores da Educação  217VCD239Z     ASTRAZENECA/FIOCRUZ
# 6               Faixa Etária      FL1939                  PFIZER
# 7               Faixa Etária      FH4750                  PFIZER
# 8               Faixa Etária  215VCD134Z     ASTRAZENECA/FIOCRUZ
# 9               Faixa Etária     210052A        SINOVAC/BUTANTAN
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0                          149            2022-07-06            2º Reforço
# 1  Organization/00394544000851            2021-10-13               2ª Dose
# 2  Organization/00394544000851            2021-07-27               1ª Dose
# 3           Organization/28290            2021-12-17               2ª Dose
# 4           Organization/28290            2022-02-17               1ª Dose
# 5             Organization/149            2022-01-18               Reforço
# 6           Organization/28290            2022-01-03               1ª Dose
# 7  Organization/00394544000851            2021-11-26               Reforço
# 8  Organization/33781055000135            2021-08-18               2ª Dose
# 9  Organization/61189445000156            2021-03-22               1ª Dose
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4            99     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 5            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 6            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 7            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 8            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 9            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
#
#   fl_capital
# 0          1
# 1          0
# 2          1
# 3          1
# 4          1
# 5          1
# 6          1
# 7          0
# 8          0
# 9          1
#
# [10 rows x 33 columns]

# %%
vacAcre_copy[['paciente_endereco_nmMunicipio','fl_capital']]
# Out:
#       paciente_endereco_nmMunicipio  fl_capital
# 0                        RIO BRANCO           1
# 1                         BRASILEIA           0
# 2                        RIO BRANCO           1
# 3                        RIO BRANCO           1
# 4                        RIO BRANCO           1
# ...                             ...         ...
# 19995                    RIO BRANCO           1
# 19996                    RIO BRANCO           1
# 19997                      CAPIXABA           0
# 19998                    RIO BRANCO           1
# 19999                    ACRELANDIA           0
#
# [20000 rows x 2 columns]

# %%
vacAcre_copy['fl_capital'].sum()
# Out:
# np.int64(9639)

# %%
(9294/20000) * 100
# Out:
# 46.47

# %% [markdown]
# ## Qual a idade média dos pacientes???

# %%
vacAcre_copy['paciente_idade'].mean()
# Out:
# np.float64(35.77845)
